# %% [markdown]
# # Data Engineering Project: Database Design & REST API Implementation
# By: Cem Bayramoglu, Semen Petrov, Annette Martin
#
# ## Project Overview
# Design and implement a relational database system with REST API access following a three-step workflow: data modeling, database implementation, and API interaction.
#
# ### **Music Streaming** - Songs, artists, albums, users, playlists, subscriptions

# %%
# @title Code to get information about top songs and such
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

def scrape_kworb_table(url, table_name):
    """
    Scrape a table from kworb.net

    Args:
        url: The URL to scrape
        table_name: A descriptive name for this table

    Returns:
        DataFrame with the scraped data
    """
    try:
        print(f"Scraping {table_name} from {url}...")

        # Fetch webpage
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table
        table = soup.find('table')

        if not table:
            print(f"  ⚠️ No table found at {url}")
            return None

        # Extract headers
        headers = []
        for th in table.find_all('th'):
            headers.append(th.text.strip())

        # Extract rows
        rows = []
        for tr in table.find_all('tr')[1:]:  # Skip header row
            cells = tr.find_all('td')
            row = [cell.text.strip() for cell in cells]
            if row:
                rows.append(row)

        # Create DataFrame
        df = pd.DataFrame(rows, columns=headers)
        print(f"  ✓ Successfully scraped {len(df)} rows")

        return df

    except Exception as e:
        print(f"  X Error scraping {table_name}: {e}")
        return None


# Define your URLs and their names
urls_to_scrape = {
    'Apple_Music_World_Wide_Songs': 'https://kworb.net/apple_songs/',
    'Billboard_Radio_Songs': 'https://kworb.net/radio/',
    'Itunes_World_Wide_Songs': 'https://kworb.net/ww/',
    'Spotify_Most_Streamed_Artists_of_All_Time': 'https://kworb.net/spotify/artists.html',
    'Spotify_Most_Streamed_Songs': 'https://kworb.net/spotify/toplists.html',
    'Spotify_Top_Artists_by_Monthly_Listeners': 'https://kworb.net/spotify/listeners.html',
    'YouTube_Archive': 'https://kworb.net/youtube/archive.html',
    'YouTube_Most_Viewed_Artists': 'https://kworb.net/youtube/archive.html',
}

# Dictionary to store all DataFrames
dataframes = {}

# Scrape each URL
for name, url in urls_to_scrape.items():
    df = scrape_kworb_table(url, name)
    if df is not None:
        dataframes[name] = df

    # Be polite - wait between requests
    time.sleep(1)

print("SCRAPING COMPLETE")
# Out:
# Scraping Apple_Music_World_Wide_Songs from https://kworb.net/apple_songs/...
#   ✓ Successfully scraped 200 rows
# Scraping Billboard_Radio_Songs from https://kworb.net/radio/...
#   ✓ Successfully scraped 167 rows
# Scraping Itunes_World_Wide_Songs from https://kworb.net/ww/...
#   ✓ Successfully scraped 200 rows
# Scraping Spotify_Most_Streamed_Artists_of_All_Time from https://kworb.net/spotify/artists.html...
#   ✓ Successfully scraped 3000 rows
# Scraping Spotify_Most_Streamed_Songs from https://kworb.net/spotify/toplists.html...
#   ✓ Successfully scraped 24 rows
# Scraping Spotify_Top_Artists_by_Monthly_Listeners from https://kworb.net/spotify/listeners.html...
#   ✓ Successfully scraped 2500 rows
# Scraping YouTube_Archive from https://kworb.net/youtube/archive.html...
#   ✓ Successfully scraped 1730 rows
# Scraping YouTube_Most_Viewed_Artists from https://kworb.net/youtube/archive.html...
#   ✓ Successfully scraped 1730 rows
# SCRAPING COMPLETE

# %%
# @title DataFrames
# Display info about each DataFrame
for name, df in dataframes.items():
    print(f"\n{name}:")
    print(f"  Rows: {len(df)}")
    print(f"  Columns: {list(df.columns)}")

# Access individual DataFrames
df_Spotify_Listeners = dataframes.get('Spotify_Listeners')
df_YouTube_Archive = dataframes.get('YouTube_Archive')
df_Pop_Charts = dataframes.get('Pop_Charts')

# Display first DataFrame as example
if df_Spotify_Listeners is not None:
    print("\n\nSpotify Listeners Preview:")
    display(df_Spotify_Listeners.head())
# Out:
# Apple_Music_World_Wide_Songs:
#   Rows: 200
#   Columns: ['Pos', 'P+', 'Artist and Title', 'Days', 'Pk', '(x?)', 'Pts', 'Pts+', 'TPts', 'US', 'UK', 'JP', 'DE']
#
# Billboard_Radio_Songs:
#   Rows: 167
#   Columns: ['Pos', 'P+', 'Artist and Title', 'Days', 'Pk', '(x?)', 'Aud', 'Aud+', 'Formats', 'PkAud', 'iTunes', 'Spotify', 'Apple M', 'Shazam']
#
# Itunes_World_Wide_Songs:
#   Rows: 200
#   Columns: ['Pos', 'P+', 'Artist and Title', 'Days', 'Pk', '(x?)', 'Pts', 'Pts+', 'TPts', 'US', 'UK', 'DE', 'AU', 'JP']
#
# Spotify_Most_Streamed_Artists_of_All_Time:
#   Rows: 3000
#   Columns: ['Artist', 'Streams', 'Daily', 'As lead', 'Solo', 'As feature']
#
# Spotify_Most_Streamed_Songs:
#   Rows: 24
#   Columns: ['', 'Artist and Title', 'Streams']
#
# Spotify_Top_Artists_by_Monthly_Listeners:
#   Rows: 2500
#   Columns: ['#', 'Artist', 'Listeners', 'Daily +/-', 'Peak', 'PkListeners']
#
# YouTube_Archive:
#   Rows: 1730
#   Columns: ['Artist', 'Total', '100M']
#
# YouTube_Most_Viewed_Artists:
#   Rows: 1730
#   Columns: ['Artist', 'Total', '100M']

# %%
# @title Saving
for name, df in dataframes.items():
    df.to_csv(f'{name}.csv', index=False)
    print(f"Saved {name}.csv")

# Find the file by clicking on the file icon in the left toolbar
  # Then download from there
# Out:
# Saved Apple_Music_World_Wide_Songs.csv
# Saved Billboard_Radio_Songs.csv
# Saved Itunes_World_Wide_Songs.csv
# Saved Spotify_Most_Streamed_Artists_of_All_Time.csv
# Saved Spotify_Most_Streamed_Songs.csv
# Saved Spotify_Top_Artists_by_Monthly_Listeners.csv
# Saved YouTube_Archive.csv
# Saved YouTube_Most_Viewed_Artists.csv

# %%
# @title Code for music metadata
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from typing import Dict, List, Optional

class MusicBrainzMetadata:
    """
    Comprehensive MusicBrainz API client
    Rate limit: 2 seconds between requests
    """

    def __init__(self, app_name: str = "MusicMetadataCollector", app_version: str = "1.0", contact: str = "annette.hatch.martin@gmail.com"):
        self.base_url = "https://musicbrainz.org/ws/2"
        self.coverart_url = "https://coverartarchive.org"
        self.headers = {
            'User-Agent': f'{app_name}/{app_version} ( {contact} )'
        }
        self.rate_limit_delay = 2.0

    def get_comprehensive_artist_metadata(self, artist_id: str) -> Dict:
        """Get ALL available metadata for an artist"""
        endpoint = f"{self.base_url}/artist/{artist_id}"
        params = {
            'fmt': 'json',
            'inc': 'recordings+releases+release-groups+works+url-rels+artist-rels+tags+ratings+genres+annotation+aliases'
        }

        response = requests.get(endpoint, headers=self.headers, params=params)
        response.raise_for_status()
        time.sleep(self.rate_limit_delay)
        return response.json()

    def search_and_get_full_artist_data(self, artist_name: str) -> Dict:
        """Search for an artist and return ALL metadata"""
        # First search for artist
        endpoint = f"{self.base_url}/artist"
        params = {
            'query': f'artist:"{artist_name}"',
            'fmt': 'json',
            'limit': 1
        }

        print(f"  Searching: {artist_name}...", end=" ")
        response = requests.get(endpoint, headers=self.headers, params=params)
        response.raise_for_status()
        data = response.json()

        if not data.get('artists'):
            print(f"❌ Not found")
            return None

        artist_id = data['artists'][0]['id']
        time.sleep(self.rate_limit_delay)

        # Get detailed artist info
        print(f"✓ Getting metadata...", end=" ")
        artist_data = self.get_comprehensive_artist_metadata(artist_id)

        # Extract URL relationships
        url_relations = artist_data.get('relations', [])
        urls = {}
        for rel in url_relations:
            rel_type = rel.get('type', '')
            url = rel.get('url', {}).get('resource', '')
            if url:
                urls[rel_type] = url

        # Extract release groups
        release_groups = artist_data.get('release-groups', [])
        albums = [rg for rg in release_groups if rg.get('primary-type') == 'Album']
        singles = [rg for rg in release_groups if rg.get('primary-type') == 'Single']
        eps = [rg for rg in release_groups if rg.get('primary-type') == 'EP']

        # Extract aliases
        aliases = [alias.get('name') for alias in artist_data.get('aliases', [])]

        print("✓ Complete")

        return {
            # Identifiers
            'artist_mbid': artist_data.get('id'),
            'isni': ', '.join(artist_data.get('isnis', [])),
            'ipi': ', '.join(artist_data.get('ipis', [])),

            # Basic Info
            'name': artist_data.get('name'),
            'sort_name': artist_data.get('sort-name'),
            'type': artist_data.get('type'),
            'country': artist_data.get('country'),
            'gender': artist_data.get('gender'),
            'disambiguation': artist_data.get('disambiguation', ''),
            'aliases': ', '.join(aliases[:5]) if aliases else '',

            # Dates
            'begin_date': artist_data.get('life-span', {}).get('begin', ''),
            'end_date': artist_data.get('life-span', {}).get('end', ''),
            'is_ended': artist_data.get('life-span', {}).get('ended', False),

            # Statistics
            'num_albums': len(albums),
            'num_singles': len(singles),
            'num_eps': len(eps),
            'total_releases': len(artist_data.get('releases', [])),
            'total_recordings': len(artist_data.get('recordings', [])),

            # Categorization
            'genres': ', '.join([g['name'] for g in artist_data.get('genres', [])]),
            'tags': ', '.join([t['name'] for t in artist_data.get('tags', [])[:10]]),

            # Community Data
            'rating': artist_data.get('rating', {}).get('value'),
            'rating_votes': artist_data.get('rating', {}).get('votes-count', 0),

            # Official Links
            'official_website': urls.get('official homepage', ''),
            'wikipedia': urls.get('wikipedia', ''),
            'wikidata': urls.get('wikidata', ''),
            'discogs': urls.get('discogs', ''),
            'allmusic': urls.get('allmusic', ''),
            'imdb': urls.get('imdb', ''),
            'bandcamp': urls.get('bandcamp', ''),

            # Streaming Platforms
            'spotify': urls.get('spotify', ''),
            'apple_music': urls.get('apple music', ''),
            'youtube': urls.get('youtube', ''),
            'youtube_music': urls.get('youtube music', ''),
            'soundcloud': urls.get('soundcloud', ''),
            'deezer': urls.get('deezer', ''),
            'tidal': urls.get('tidal', ''),
            'amazon_music': urls.get('amazon music', ''),

            # Social Media
            'twitter': urls.get('twitter', ''),
            'instagram': urls.get('instagram', ''),
            'facebook': urls.get('facebook', ''),
            'tiktok': urls.get('tiktok', ''),
            'linkedin': urls.get('linkedin', ''),

            # Other
            'lyrics': urls.get('lyrics', ''),
            'purchase_url': urls.get('purchase for mail-order', ''),
            'crowdfunding': urls.get('crowdfunding', ''),
        }

    def get_multiple_artists_metadata(self, artist_names: List[str]) -> pd.DataFrame:
        """Get comprehensive metadata for multiple artists"""
        all_artists_data = []

        print(f"\n{'='*70}")
        print(f"Fetching metadata for {len(artist_names)} artists")
        print(f"Rate limit: {self.rate_limit_delay} seconds between requests")
        print(f"Estimated time: {len(artist_names) * self.rate_limit_delay * 2 / 60:.1f} minutes")
        print(f"{'='*70}\n")

        for idx, artist_name in enumerate(artist_names, 1):
            print(f"[{idx}/{len(artist_names)}]", end=" ")

            try:
                artist_data = self.search_and_get_full_artist_data(artist_name)

                if artist_data:
                    all_artists_data.append(artist_data)
                else:
                    all_artists_data.append({'name': artist_name})

            except Exception as e:
                print(f"  ❌ Error: {e}")
                all_artists_data.append({'name': artist_name, 'error': str(e)})

        print(f"\n{'='*70}")
        print(f"✅ Completed: {len(all_artists_data)} artists processed")
        print(f"{'='*70}\n")

        return pd.DataFrame(all_artists_data)


def scrape_kworb_top_artists(url: str, limit: int = 2000) -> List[str]:
    """
    Scrape top artists from kworb.net

    Args:
        url: kworb.net URL (e.g., 'https://kworb.net/spotify/listeners.html')
        limit: Maximum number of artists to retrieve (default 2000)

    Returns:
        List of artist names
    """
    print(f"\n{'='*70}")
    print(f"Scraping top {limit} artists from kworb.net")
    print(f"{'='*70}\n")

    response = requests.get(url)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')

    table = soup.find('table')
    if not table:
        raise Exception("No table found on page")

    artists = []
    rows = table.find_all('tr')[1:]  # Skip header

    for idx, tr in enumerate(rows[:limit], 1):
        cells = tr.find_all('td')
        if len(cells) >= 2:  # Make sure there are enough columns
            # Usually artist is in the second column (index 1)
            artist_name = cells[1].text.strip()
            if artist_name:
                artists.append(artist_name)
                if idx % 100 == 0:
                    print(f"  Scraped {idx} artists...")

    print(f"\n✓ Successfully scraped {len(artists)} artists from kworb.net\n")
    return artists


# ============================================================================
# Main Execution
# ============================================================================
print("="*70)
print("AUTOMATIC TOP ARTISTS METADATA COLLECTOR")
print("="*70)
print(f"Email: annette.hatch.martin@gmail.com")
print(f"Rate Limit: 2 seconds between requests")
print("="*70)

# Initialize API client
mb = MusicBrainzMetadata(
    app_name="AutoTopArtistsCollector",
    app_version="1.0",
    contact="annette.hatch.martin@gmail.com"
)

# Step 1: Scrape top artists from kworb.net
kworb_url = "https://kworb.net/spotify/listeners.html"
num_artists = 2000  # Start with 100 for testing - change to 2000 for full run

print("\n⚠️  IMPORTANT: Starting with 100 artists for testing")
print("⚠️  Change 'num_artists = 2000' in the code for the full dataset")
print("⚠️  Full run (2000 artists) will take ~2 hours with 2-second rate limit\n")

top_artists = scrape_kworb_top_artists(kworb_url, limit=num_artists)

# Step 2: Get MusicBrainz metadata for all artists
df_artists = mb.get_multiple_artists_metadata(top_artists)

# Display results
print("\n" + "="*70)
print("RESULTS SUMMARY")
print("="*70)
print(f"Total artists processed: {len(df_artists)}")
print(f"Successful matches: {df_artists['artist_mbid'].notna().sum()}")
print(f"Failed matches: {df_artists['artist_mbid'].isna().sum()}")
print(f"\nDataFrame shape: {df_artists.shape[0]} rows × {df_artists.shape[1]} columns")

print("\n📊 COLUMN HEADERS (Metadata Fields):")
for col in df_artists.columns:
    print(f"  • {col}")

print("\n\nPreview of first 5 artists:")
display(df_artists.head())

print("\n\n💾 SAVE OPTIONS:")
print("  df_artists.to_csv('top_artists_metadata.csv', index=False)")
print("  df_artists.to_json('top_artists_metadata.json', orient='records')")
print("  df_artists.to_excel('top_artists_metadata.xlsx', index=False)")

print("\n✅ Ready! DataFrame stored in variable: df_artists")
# Out:
# ======================================================================
# AUTOMATIC TOP ARTISTS METADATA COLLECTOR
# ======================================================================
# Email: annette.hatch.martin@gmail.com
# Rate Limit: 2 seconds between requests
# ======================================================================
#
# ⚠️  IMPORTANT: Starting with 100 artists for testing
# ⚠️  Change 'num_artists = 2000' in the code for the full dataset
# ⚠️  Full run (2000 artists) will take ~2 hours with 2-second rate limit
#
#
# ======================================================================
# Scraping top 2000 artists from kworb.net
# ======================================================================
#
#   Scraped 100 artists...
#   Scraped 200 artists...
#   Scraped 300 artists...
#   Scraped 400 artists...
#   Scraped 500 artists...
#   Scraped 600 artists...
#   Scraped 700 artists...
#   Scraped 800 artists...
#   Scraped 900 artists...
#   Scraped 1000 artists...
#   Scraped 1100 artists...
#   Scraped 1200 artists...
#   Scraped 1300 artists...
#   Scraped 1400 artists...
#   Scraped 1500 artists...
#   Scraped 1600 artists...
#   Scraped 1700 artists...
#   Scraped 1800 artists...
#   Scraped 1900 artists...
#   Scraped 2000 artists...
#
# ✓ Successfully scraped 2000 artists from kworb.net
#
#
# ======================================================================
# Fetching metadata for 2000 artists
# Rate limit: 2.0 seconds between requests
# Estimated time: 133.3 minutes
# ======================================================================
#
# [1/2000]   Searching: Bruno Mars... ✓ Getting metadata... ✓ Complete
# [2/2000]   Searching: The Weeknd... ✓ Getting metadata... ✓ Complete
# [3/2000]   Searching: Justin Bieber... ✓ Getting metadata... ✓ Complete
# [4/2000]   Searching: Ariana Grande... ✓ Getting metadata... ✓ Complete
# [5/2000]   Searching: Taylor Swift... ✓ Getting metadata... ✓ Complete
# [6/2000]   Searching: Rihanna... ✓ Getting metadata... ✓ Complete
# [7/2000]   Searching: Coldplay... ✓ Getting metadata... ✓ Complete
# [8/2000]   Searching: Lady Gaga... ✓ Getting metadata... ✓ Complete
# [9/2000]   Searching: Ed Sheeran... ✓ Getting metadata... ✓ Complete
# [10/2000]   Searching: Sia... ✓ Getting metadata... ✓ Complete
# [11/2000]   Searching: Billie Eilish... ✓ Getting metadata... ✓ Complete
# [12/2000]   Searching: Drake... ✓ Getting metadata... ✓ Complete
# [13/2000]   Searching: Bad Bunny... ✓ Getting metadata... ✓ Complete
# [14/2000]   Searching: Mariah Carey... ✓ Getting metadata... ✓ Complete
# [15/2000]   Searching: Sabrina Carpenter... ✓ Getting metadata... ✓ Complete
# [16/2000]   Searching: David Guetta... ✓ Getting metadata... ✓ Complete
# [17/2000]   Searching: Shakira... ✓ Getting metadata... ✓ Complete
# [18/2000]   Searching: Maroon 5... ✓ Getting metadata... ✓ Complete
# [19/2000]   Searching: Kendrick Lamar... ✓ Getting metadata... ✓ Complete
# [20/2000]   Searching: Eminem... ✓ Getting metadata... ✓ Complete
# [21/2000]   Searching: SZA... ✓ Getting metadata... ✓ Complete
# [22/2000]   Searching: J Balvin... ✓ Getting metadata... ✓ Complete
# [23/2000]   Searching: Calvin Harris... ✓ Getting metadata... ✓ Complete
# [24/2000]   Searching: Elton John... ✓ Getting metadata... ✓ Complete
# [25/2000]   Searching: Katy Perry... ✓ Getting metadata... ✓ Complete
# [26/2000]   Searching: Kanye West... ✓ Getting metadata... ✓ Complete
# [27/2000]   Searching: Dua Lipa... ✓ Getting metadata... ✓ Complete
# [28/2000]   Searching: Pitbull... ✓ Getting metadata... ✓ Complete
# [29/2000]   Searching: Post Malone... ✓ Getting metadata... ✓ Complete
# [30/2000]   Searching: Queen... ✓ Getting metadata... ✓ Complete
# [31/2000]   Searching: Lana Del Rey... ✓ Getting metadata... ✓ Complete
# [32/2000]   Searching: Daddy Yankee... ✓ Getting metadata... ✓ Complete
# [33/2000]   Searching: Michael Jackson... ✓ Getting metadata... ✓ Complete
# [34/2000]   Searching: Chris Brown... ✓ Getting metadata... ✓ Complete
# [35/2000]   Searching: Travis Scott... ✓ Getting metadata... ✓ Complete
# [36/2000]   Searching: Olivia Dean... ✓ Getting metadata... ✓ Complete
# [37/2000]   Searching: Wham!... ✓ Getting metadata... ✓ Complete
# [38/2000]   Searching: Michael Bublé... ✓ Getting metadata... ✓ Complete
# [39/2000]   Searching: Doja Cat... ✓ Getting metadata... ✓ Complete
# [40/2000]   Searching: Black Eyed Peas... ✓ Getting metadata... ✓ Complete
# [41/2000]   Searching: Adele... ✓ Getting metadata... ✓ Complete
# [42/2000]   Searching: Djo... ✓ Getting metadata... ✓ Complete
# [43/2000]   Searching: Britney Spears... ✓ Getting metadata... ✓ Complete
# [44/2000]   Searching: Arijit Singh... ✓ Getting metadata... ✓ Complete
# [45/2000]   Searching: sombr... ✓ Getting metadata... ✓ Complete
# [46/2000]   Searching: Imagine Dragons... ✓ Getting metadata... ✓ Complete
# [47/2000]   Searching: Miley Cyrus... ✓ Getting metadata... ✓ Complete
# [48/2000]   Searching: Beyoncé... ✓ Getting metadata... ✓ Complete
# [49/2000]   Searching: Sam Smith... ✓ Getting metadata... ✓ Complete
# [50/2000]   Searching: Arctic Monkeys... ✓ Getting metadata... ✓ Complete
# [51/2000]   Searching: Shreya Ghoshal... ✓ Getting metadata... ✓ Complete
# [52/2000]   Searching: Sean Paul... ✓ Getting metadata... ✓ Complete
# [53/2000]   Searching: KPop Demon Hunters Cast... ✓ Getting metadata... ✓ Complete
# [54/2000]   Searching: RAYE... ✓ Getting metadata... ✓ Complete
# [55/2000]   Searching: Future... ✓ Getting metadata... ✓ Complete
# [56/2000]   Searching: Tate McRae... ✓ Getting metadata... ✓ Complete
# [57/2000]   Searching: Kelly Clarkson... ✓ Getting metadata... ✓ Complete
# [58/2000]   Searching: Linkin Park... ✓ Getting metadata... ✓ Complete
# [59/2000]   Searching: Rauw Alejandro... ✓ Getting metadata... ✓ Complete
# [60/2000]   Searching: Zara Larsson... ✓ Getting metadata... ✓ Complete
# [61/2000]   Searching: Halsey... ✓ Getting metadata... ✓ Complete
# [62/2000]   Searching: Fleetwood Mac... ✓ Getting metadata... ✓ Complete
# [63/2000]   Searching: Ozuna... ✓ Getting metadata... ✓ Complete
# [64/2000]   Searching: Brenda Lee... ✓ Getting metadata... ✓ Complete
# [65/2000]   Searching: The Police... ✓ Getting metadata... ✓ Complete
# [66/2000]   Searching: Frank Sinatra... ✓ Getting metadata... ✓ Complete
# [67/2000]   Searching: Harry Styles... ✓ Getting metadata... ✓ Complete
# [68/2000]   Searching: Alex Warren... ✓ Getting metadata... ✓ Complete
# [69/2000]   Searching: KAROL G... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [70/2000]   Searching: Pritam... ✓ Getting metadata... ✓ Complete
# [71/2000]   Searching: EJAE... ✓ Getting metadata... ✓ Complete
# [72/2000]   Searching: The Chainsmokers... ✓ Getting metadata... ✓ Complete
# [73/2000]   Searching: DJ Snake... ✓ Getting metadata... ✓ Complete
# [74/2000]   Searching: A.R. Rahman... ❌ Not found
# [75/2000]   Searching: Marshmello... ✓ Getting metadata... ✓ Complete
# [76/2000]   Searching: REI AMI... ✓ Getting metadata... ✓ Complete
# [77/2000]   Searching: OneRepublic... ✓ Getting metadata... ✓ Complete
# [78/2000]   Searching: Shawn Mendes... ✓ Getting metadata... ✓ Complete
# [79/2000]   Searching: HUNTR/X... ✓ Getting metadata... ✓ Complete
# [80/2000]   Searching: Khalid... ✓ Getting metadata... ✓ Complete
# [81/2000]   Searching: Teddy Swims... ✓ Getting metadata... ✓ Complete
# [82/2000]   Searching: AUDREY NUNA... ✓ Getting metadata... ✓ Complete
# [83/2000]   Searching: 50 Cent... ✓ Getting metadata... ✓ Complete
# [84/2000]   Searching: Playboi Carti... ✓ Getting metadata... ✓ Complete
# [85/2000]   Searching: Olivia Rodrigo... ✓ Getting metadata... ✓ Complete
# [86/2000]   Searching: Dean Martin... ✓ Getting metadata... ✓ Complete
# [87/2000]   Searching: Lil Wayne... ✓ Getting metadata... ✓ Complete
# [88/2000]   Searching: Tyla... ✓ Getting metadata... ✓ Complete
# [89/2000]   Searching: Charlie Puth... ✓ Getting metadata... ✓ Complete
# [90/2000]   Searching: Justin Timberlake... ✓ Getting metadata... ✓ Complete
# [91/2000]   Searching: ABBA... ✓ Getting metadata... ✓ Complete
# [92/2000]   Searching: The Neighbourhood... ✓ Getting metadata... ✓ Complete
# [93/2000]   Searching: Camila Cabello... ✓ Getting metadata... ✓ Complete
# [94/2000]   Searching: Benson Boone... ✓ Getting metadata... ✓ Complete
# [95/2000]   Searching: Ellie Goulding... ✓ Getting metadata... ✓ Complete
# [96/2000]   Searching: Nicki Minaj... ✓ Getting metadata... ✓ Complete
# [97/2000]   Searching: USHER... ✓ Getting metadata... ✓ Complete
# [98/2000]   Searching: Don Omar... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [99/2000]   Searching: Ne-Yo... ✓ Getting metadata... ✓ Complete
# [100/2000]   Searching: Radiohead... ✓ Getting metadata... ✓ Complete
# [101/2000]   Searching: One Direction... ✓ Getting metadata... ✓ Complete
# [102/2000]   Searching: Madonna... ✓ Getting metadata... ✓ Complete
# [103/2000]   Searching: Maluma... ✓ Getting metadata... ✓ Complete
# [104/2000]   Searching: Fuerza Regida... ✓ Getting metadata... ✓ Complete
# [105/2000]   Searching: Farruko... ✓ Getting metadata... ✓ Complete
# [106/2000]   Searching: Metro Boomin... ✓ Getting metadata... ✓ Complete
# [107/2000]   Searching: Tyler, The Creator... ✓ Getting metadata... ✓ Complete
# [108/2000]   Searching: Bobby Helms... ✓ Getting metadata... ✓ Complete
# [109/2000]   Searching: Red Hot Chili Peppers... ✓ Getting metadata... ✓ Complete
# [110/2000]   Searching: JENNIE... ✓ Getting metadata... ✓ Complete
# [111/2000]   Searching: Peso Pluma... ✓ Getting metadata... ✓ Complete
# [112/2000]   Searching: 21 Savage... ✓ Getting metadata... ✓ Complete
# [113/2000]   Searching: Kesha... ✓ Getting metadata... ✓ Complete
# [114/2000]   Searching: Anuel AA...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [115/2000]   Searching: The Ronettes... ✓ Getting metadata... ✓ Complete
# [116/2000]   Searching: Hozier... ✓ Getting metadata... ✓ Complete
# [117/2000]   Searching: Disney... ✓ Getting metadata... ✓ Complete
# [118/2000]   Searching: Elvis Presley... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [119/2000]   Searching: Akon... ✓ Getting metadata... ✓ Complete
# [120/2000]   Searching: Selena Gomez... ✓ Getting metadata... ✓ Complete
# [121/2000]   Searching: Eagles... ✓ Getting metadata... ✓ Complete
# [122/2000]   Searching: Wiz Khalifa... ✓ Getting metadata... ✓ Complete
# [123/2000]   Searching: Daniel Caesar... ✓ Getting metadata... ✓ Complete
# [124/2000]   Searching: Don Toliver... ✓ Getting metadata... ✓ Complete
# [125/2000]   Searching: Flo Rida... ✓ Getting metadata... ✓ Complete
# [126/2000]   Searching: Tame Impala... ✓ Getting metadata... ✓ Complete
# [127/2000]   Searching: JAY-Z... ✓ Getting metadata... ✓ Complete
# [128/2000]   Searching: Romeo Santos... ✓ Getting metadata... ✓ Complete
# [129/2000]   Searching: Laufey...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [130/2000]   Searching: Nat King Cole... ✓ Getting metadata... ✓ Complete
# [131/2000]   Searching: A$AP Rocky... ✓ Getting metadata... ✓ Complete
# [132/2000]   Searching: Beéle... ✓ Getting metadata... ✓ Complete
# [133/2000]   Searching: Kali Uchis... ✓ Getting metadata... ✓ Complete
# [134/2000]   Searching: Irshad Kamil... ✓ Getting metadata... ✓ Complete
# [135/2000]   Searching: Avicii... ✓ Getting metadata... ✓ Complete
# [136/2000]   Searching: Sachin-Jigar... ✓ Getting metadata... ✓ Complete
# [137/2000]   Searching: John Lennon... ✓ Getting metadata... ✓ Complete
# [138/2000]   Searching: Gorillaz... ✓ Getting metadata... ✓ Complete
# [139/2000]   Searching: Gracie Abrams... ✓ Getting metadata... ✓ Complete
# [140/2000]   Searching: The Kid LAROI... ✓ Getting metadata... ✓ Complete
# [141/2000]   Searching: Chappell Roan... ✓ Getting metadata... ✓ Complete
# [142/2000]   Searching: Andy Williams... ✓ Getting metadata... ✓ Complete
# [143/2000]   Searching: KATSEYE... ✓ Getting metadata... ✓ Complete
# [144/2000]   Searching: Grupo Frontera... ✓ Getting metadata... ✓ Complete
# [145/2000]   Searching: Anitta... ✓ Getting metadata... ✓ Complete
# [146/2000]   Searching: Twenty One Pilots... ✓ Getting metadata... ✓ Complete
# [147/2000]   Searching: Vishal-Shekhar... ✓ Getting metadata... ✓ Complete
# [148/2000]   Searching: José Feliciano... ✓ Getting metadata... ✓ Complete
# [149/2000]   Searching: Myke Towers... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [150/2000]   Searching: Nirvana... ✓ Getting metadata... ✓ Complete
# [151/2000]   Searching: The Marías... ✓ Getting metadata... ✓ Complete
# [152/2000]   Searching: ROSALÍA... ✓ Getting metadata... ✓ Complete
# [153/2000]   Searching: Frank Ocean... ✓ Getting metadata... ✓ Complete
# [154/2000]   Searching: AC/DC... ✓ Getting metadata... ✓ Complete
# [155/2000]   Searching: Feid... ✓ Getting metadata... ✓ Complete
# [156/2000]   Searching: Ovy On The Drums...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [157/2000]   Searching: Alicia Keys... ✓ Getting metadata... ✓ Complete
# [158/2000]   Searching: Swae Lee... ✓ Getting metadata... ✓ Complete
# [159/2000]   Searching: Ty Dolla $ign... ✓ Getting metadata... ✓ Complete
# [160/2000]   Searching: Tinashe... ✓ Getting metadata... ✓ Complete
# [161/2000]   Searching: Udit Narayan... ✓ Getting metadata... ✓ Complete
# [162/2000]   Searching: Gwen Stefani... ✓ Getting metadata... ✓ Complete
# [163/2000]   Searching: Amitabh Bhattacharya... ✓ Getting metadata... ✓ Complete
# [164/2000]   Searching: Guns N' Roses... ✓ Getting metadata... ✓ Complete
# [165/2000]   Searching: Tiësto... ✓ Getting metadata... ✓ Complete
# [166/2000]   Searching: ROSÉ... ✓ Getting metadata... ✓ Complete
# [167/2000]   Searching: Diplo... ✓ Getting metadata... ✓ Complete
# [168/2000]   Searching: Paul McCartney... ✓ Getting metadata... ✓ Complete
# [169/2000]   Searching: The Goo Goo Dolls... ❌ Not found
# [170/2000]   Searching: Nicky Jam... ✓ Getting metadata... ✓ Complete
# [171/2000]   Searching: Manuel Turizo... ✓ Getting metadata... ✓ Complete
# [172/2000]   Searching: Green Day... ✓ Getting metadata... ✓ Complete
# [173/2000]   Searching: The Beatles... ✓ Getting metadata... ✓ Complete
# [174/2000]   Searching: P!nk... ✓ Getting metadata... ✓ Complete
# [175/2000]   Searching: Ava Max... ✓ Getting metadata... ✓ Complete
# [176/2000]   Searching: Empire Of The Sun... ✓ Getting metadata... ✓ Complete
# [177/2000]   Searching: Whitney Houston... ✓ Getting metadata... ✓ Complete
# [178/2000]   Searching: Tanishk Bagchi... ✓ Getting metadata... ✓ Complete
# [179/2000]   Searching: J. Cole... ✓ Getting metadata... ✓ Complete
# [180/2000]   Searching: Pharrell Williams... ✓ Getting metadata... ✓ Complete
# [181/2000]   Searching: Billy Joel... ✓ Getting metadata... ✓ Complete
# [182/2000]   Searching: Gunna... ✓ Getting metadata... ✓ Complete
# [183/2000]   Searching: Cigarettes After Sex... ✓ Getting metadata... ✓ Complete
# [184/2000]   Searching: Ravyn Lenae... ✓ Getting metadata... ✓ Complete
# [185/2000]   Searching: XXXTENTACION... ✓ Getting metadata... ✓ Complete
# [186/2000]   Searching: Morgan Wallen... ✓ Getting metadata... ✓ Complete
# [187/2000]   Searching: Nelly Furtado... ✓ Getting metadata... ✓ Complete
# [188/2000]   Searching: Christina Aguilera... ✓ Getting metadata... ✓ Complete
# [189/2000]   Searching: Bruce Springsteen... ✓ Getting metadata... ✓ Complete
# [190/2000]   Searching: John Legend...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [191/2000]   Searching: Bebe Rexha... ✓ Getting metadata... ✓ Complete
# [192/2000]   Searching: Meghan Trainor... ✓ Getting metadata... ✓ Complete
# [193/2000]   Searching: Bon Jovi... ✓ Getting metadata... ✓ Complete
# [194/2000]   Searching: Metallica... ✓ Getting metadata... ✓ Complete
# [195/2000]   Searching: Fall Out Boy... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [196/2000]   Searching: Enrique Iglesias... ✓ Getting metadata... ✓ Complete
# [197/2000]   Searching: Daryl Hall & John Oates... ✓ Getting metadata... ✓ Complete
# [198/2000]   Searching: Atif Aslam... ✓ Getting metadata... ✓ Complete
# [199/2000]   Searching: Bryan Adams... ✓ Getting metadata... ✓ Complete
# [200/2000]   Searching: Bing Crosby... ✓ Getting metadata... ✓ Complete
# [201/2000]   Searching: Anne-Marie... ✓ Getting metadata... ✓ Complete
# [202/2000]   Searching: Lord Huron... ✓ Getting metadata... ✓ Complete
# [203/2000]   Searching: Lil Baby... ✓ Getting metadata... ✓ Complete
# [204/2000]   Searching: Gigi Perez... ✓ Getting metadata... ✓ Complete
# [205/2000]   Searching: James Arthur... ✓ Getting metadata... ✓ Complete
# [206/2000]   Searching: Oasis... ✓ Getting metadata... ✓ Complete
# [207/2000]   Searching: Juice WRLD... ✓ Getting metadata... ✓ Complete
# [208/2000]   Searching: The Killers... ✓ Getting metadata... ✓ Complete
# [209/2000]   Searching: Creedence Clearwater Revival... ✓ Getting metadata... ✓ Complete
# [210/2000]   Searching: Jennifer Lopez... ✓ Getting metadata... ✓ Complete
# [211/2000]   Searching: Shankar Mahadevan... ✓ Getting metadata... ✓ Complete
# [212/2000]   Searching: Mark Ronson... ✓ Getting metadata... ✓ Complete
# [213/2000]   Searching: Bizarrap... ✓ Getting metadata... ✓ Complete
# [214/2000]   Searching: Major Lazer... ✓ Getting metadata... ✓ Complete
# [215/2000]   Searching: KK... ✓ Getting metadata... ✓ Complete
# [216/2000]   Searching: Tom Odell... ✓ Getting metadata... ✓ Complete
# [217/2000]   Searching: Mithoon... ✓ Getting metadata... ✓ Complete
# [218/2000]   Searching: Tears For Fears... ✓ Getting metadata... ✓ Complete
# [219/2000]   Searching: Demi Lovato... ✓ Getting metadata... ✓ Complete
# [220/2000]   Searching: Lil Uzi Vert... ✓ Getting metadata... ✓ Complete
# [221/2000]   Searching: TOTO... ✓ Getting metadata... ✓ Complete
# [222/2000]   Searching: Paramore... ✓ Getting metadata... ✓ Complete
# [223/2000]   Searching: Sonu Nigam... ✓ Getting metadata... ✓ Complete
# [224/2000]   Searching: PARTYNEXTDOOR... ✓ Getting metadata... ✓ Complete
# [225/2000]   Searching: ZAYN... ✓ Getting metadata... ✓ Complete
# [226/2000]   Searching: Stevie Wonder... ✓ Getting metadata... ✓ Complete
# [227/2000]   Searching: Snoop Dogg... ✓ Getting metadata... ✓ Complete
# [228/2000]   Searching: Clean Bandit... ✓ Getting metadata... ✓ Complete
# [229/2000]   Searching: Cardi B... ✓ Getting metadata... ✓ Complete
# [230/2000]   Searching: JHAYCO... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [231/2000]   Searching: Cris MJ... ✓ Getting metadata... ✓ Complete
# [232/2000]   Searching: Alan Walker... ✓ Getting metadata... ✓ Complete
# [233/2000]   Searching: Neton Vega... ✓ Getting metadata... ✓ Complete
# [234/2000]   Searching: Junior H... ✓ Getting metadata... ✓ Complete
# [235/2000]   Searching: Chinmayi... ✓ Getting metadata... ✓ Complete
# [236/2000]   Searching: Charli xcx... ✓ Getting metadata... ✓ Complete
# [237/2000]   Searching: Lola Young... ✓ Getting metadata... ✓ Complete
# [238/2000]   Searching: Arcángel... ✓ Getting metadata... ✓ Complete
# [239/2000]   Searching: Childish Gambino... ✓ Getting metadata... ✓ Complete
# [240/2000]   Searching: Tems... ✓ Getting metadata... ✓ Complete
# [241/2000]   Searching: Carín León... ✓ Getting metadata... ✓ Complete
# [242/2000]   Searching: Mohit Chauhan... ✓ Getting metadata... ✓ Complete
# [243/2000]   Searching: Kehlani... ✓ Getting metadata... ✓ Complete
# [244/2000]   Searching: Young Thug... ✓ Getting metadata... ✓ Complete
# [245/2000]   Searching: George Michael... ✓ Getting metadata... ✓ Complete
# [246/2000]   Searching: Jason Derulo...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [247/2000]   Searching: 2Pac... ✓ Getting metadata... ✓ Complete
# [248/2000]   Searching: Lewis Capaldi... ✓ Getting metadata... ✓ Complete
# [249/2000]   Searching: Quevedo... ✓ Getting metadata... ✓ Complete
# [250/2000]   Searching: Jonas Brothers... ✓ Getting metadata... ✓ Complete
# [251/2000]   Searching: Backstreet Boys... ✓ Getting metadata... ✓ Complete
# [252/2000]   Searching: The Cranberries... ✓ Getting metadata... ✓ Complete
# [253/2000]   Searching: Alka Yagnik... ✓ Getting metadata... ✓ Complete
# [254/2000]   Searching: Bee Gees... ✓ Getting metadata... ✓ Complete
# [255/2000]   Searching: Macklemore... ✓ Getting metadata... ✓ Complete
# [256/2000]   Searching: Céline Dion... ✓ Getting metadata... ✓ Complete
# [257/2000]   Searching: Lily-Rose Depp... ✓ Getting metadata... ✓ Complete
# [258/2000]   Searching: Luis Fonsi... ✓ Getting metadata... ✓ Complete
# [259/2000]   Searching: The Script... ✓ Getting metadata... ✓ Complete
# [260/2000]   Searching: Yoko Ono... ✓ Getting metadata... ✓ Complete
# [261/2000]   Searching: Wisin & Yandel... ✓ Getting metadata... ✓ Complete
# [262/2000]   Searching: Timbaland... ✓ Getting metadata... ✓ Complete
# [263/2000]   Searching: Disco Lines... ✓ Getting metadata... ✓ Complete
# [264/2000]   Searching: Miguel... ✓ Getting metadata... ✓ Complete
# [265/2000]   Searching: Florence + The Machine... ✓ Getting metadata... ✓ Complete
# [266/2000]   Searching: Phil Collins... ✓ Getting metadata... ✓ Complete
# [267/2000]   Searching: Kate Bush... ✓ Getting metadata... ✓ Complete
# [268/2000]   Searching: The Rolling Stones... ✓ Getting metadata... ✓ Complete
# [269/2000]   Searching: Tainy... ✓ Getting metadata... ✓ Complete
# [270/2000]   Searching: Daft Punk... ✓ Getting metadata... ✓ Complete
# [271/2000]   Searching: Pink Floyd... ✓ Getting metadata... ✓ Complete
# [272/2000]   Searching: Shankar-Ehsaan-Loy... ✓ Getting metadata... ✓ Complete
# [273/2000]   Searching: El Bogueto... ✓ Getting metadata... ✓ Complete
# [274/2000]   Searching: Blessd... ✓ Getting metadata... ✓ Complete
# [275/2000]   Searching: Vishal Mishra... ✓ Getting metadata... ✓ Complete
# [276/2000]   Searching: Manoj Muntashir... ✓ Getting metadata... ✓ Complete
# [277/2000]   Searching: The Notorious B.I.G.... ✓ Getting metadata... ✓ Complete
# [278/2000]   Searching: Kid Cudi... ✓ Getting metadata... ✓ Complete
# [279/2000]   Searching: Swedish House Mafia... ✓ Getting metadata... ✓ Complete
# [280/2000]   Searching: French Montana... ✓ Getting metadata... ✓ Complete
# [281/2000]   Searching: Plan B... ✓ Getting metadata... ✓ Complete
# [282/2000]   Searching: Kumaar... ✓ Getting metadata... ✓ Complete
# [283/2000]   Searching: Bob Marley & The Wailers... ✓ Getting metadata... ✓ Complete
# [284/2000]   Searching: Lorde... ✓ Getting metadata... ✓ Complete
# [285/2000]   Searching: DaBaby... ✓ Getting metadata... ✓ Complete
# [286/2000]   Searching: Dire Straits... ✓ Getting metadata... ✓ Complete
# [287/2000]   Searching: a-ha... ✓ Getting metadata... ✓ Complete
# [288/2000]   Searching: Darlene Love... ✓ Getting metadata... ✓ Complete
# [289/2000]   Searching: Mac Miller... ✓ Getting metadata... ✓ Complete
# [290/2000]   Searching: Zach Bryan... ✓ Getting metadata... ✓ Complete
# [291/2000]   Searching: Shilpa Rao... ✓ Getting metadata... ✓ Complete
# [292/2000]   Searching: Sunidhi Chauhan... ✓ Getting metadata... ✓ Complete
# [293/2000]   Searching: Kodak Black... ✓ Getting metadata... ✓ Complete
# [294/2000]   Searching: Doechii... ✓ Getting metadata... ✓ Complete
# [295/2000]   Searching: Himesh Reshammiya... ✓ Getting metadata... ✓ Complete
# [296/2000]   Searching: Zion & Lennox... ✓ Getting metadata... ✓ Complete
# [297/2000]   Searching: John Williams... ✓ Getting metadata... ✓ Complete
# [298/2000]   Searching: BTS... ✓ Getting metadata... ✓ Complete
# [299/2000]   Searching: Tito Double P... ✓ Getting metadata... ✓ Complete
# [300/2000]   Searching: Pentatonix... ✓ Getting metadata... ✓ Complete
# [301/2000]   Searching: Trippie Redd... ✓ Getting metadata... ✓ Complete
# [302/2000]   Searching: Chris Stapleton... ✓ Getting metadata... ✓ Complete
# [303/2000]   Searching: Yung Beef... ✓ Getting metadata... ✓ Complete
# [304/2000]   Searching: The Beach Boys... ✓ Getting metadata... ✓ Complete
# [305/2000]   Searching: AFROJACK... ✓ Getting metadata... ✓ Complete
# [306/2000]   Searching: Joji... ✓ Getting metadata... ✓ Complete
# [307/2000]   Searching: Chencho Corleone... ✓ Getting metadata... ✓ Complete
# [308/2000]   Searching: Aerosmith... ✓ Getting metadata... ✓ Complete
# [309/2000]   Searching: GIVĒON... ✓ Getting metadata... ✓ Complete
# [310/2000]   Searching: Luke Combs... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [311/2000]   Searching: Maná... ✓ Getting metadata... ✓ Complete
# [312/2000]   Searching: Sade... ✓ Getting metadata... ✓ Complete
# [313/2000]   Searching: Chuck Berry... ✓ Getting metadata... ✓ Complete
# [314/2000]   Searching: Vance Joy... ✓ Getting metadata... ✓ Complete
# [315/2000]   Searching: El Alfa... ✓ Getting metadata... ✓ Complete
# [316/2000]   Searching: Luis Miguel... ✓ Getting metadata... ✓ Complete
# [317/2000]   Searching: Anirudh Ravichander... ✓ Getting metadata... ✓ Complete
# [318/2000]   Searching: Rels B... ✓ Getting metadata... ✓ Complete
# [319/2000]   Searching: Ryan Castro... ✓ Getting metadata... ✓ Complete
# [320/2000]   Searching: Noah Kahan... ✓ Getting metadata... ✓ Complete
# [321/2000]   Searching: Central Cee... ✓ Getting metadata... ✓ Complete
# [322/2000]   Searching: Becky G... ✓ Getting metadata... ✓ Complete
# [323/2000]   Searching: Shaggy... ✓ Getting metadata... ✓ Complete
# [324/2000]   Searching: Aventura... ✓ Getting metadata... ✓ Complete
# [325/2000]   Searching: Journey... ✓ Getting metadata... ✓ Complete
# [326/2000]   Searching: Sayeed Quadri... ❌ Not found
# [327/2000]   Searching: Keane... ✓ Getting metadata... ✓ Complete
# [328/2000]   Searching: Vishal Dadlani... ✓ Getting metadata... ✓ Complete
# [329/2000]   Searching: BLACKPINK... ✓ Getting metadata... ✓ Complete
# [330/2000]   Searching: Kygo... ✓ Getting metadata... ✓ Complete
# [331/2000]   Searching: Danny Ocean... ✓ Getting metadata... ✓ Complete
# [332/2000]   Searching: Prince Royce... ✓ Getting metadata... ✓ Complete
# [333/2000]   Searching: Shashwat Sachdev... ✓ Getting metadata... ✓ Complete
# [334/2000]   Searching: Robin Schulz... ✓ Getting metadata... ✓ Complete
# [335/2000]   Searching: Outkast... ✓ Getting metadata... ✓ Complete
# [336/2000]   Searching: Steve Lacy... ✓ Getting metadata... ✓ Complete
# [337/2000]   Searching: Faheem Abdullah... ✓ Getting metadata... ✓ Complete
# [338/2000]   Searching: Natanael Cano... ✓ Getting metadata... ✓ Complete
# [339/2000]   Searching: G-Eazy... ✓ Getting metadata... ✓ Complete
# [340/2000]   Searching: d4vd... ✓ Getting metadata... ✓ Complete
# [341/2000]   Searching: Conan Gray... ✓ Getting metadata... ✓ Complete
# [342/2000]   Searching: Tory Lanez... ✓ Getting metadata... ✓ Complete
# [343/2000]   Searching: Aditya Rikhari... ✓ Getting metadata... ✓ Complete
# [344/2000]   Searching: Dr. Dre... ✓ Getting metadata... ✓ Complete
# [345/2000]   Searching: Evanescence... ✓ Getting metadata... ✓ Complete
# [346/2000]   Searching: Madison Beer... ✓ Getting metadata... ✓ Complete
# [347/2000]   Searching: System Of A Down... ✓ Getting metadata... ✓ Complete
# [348/2000]   Searching: Oscar Maydon... ✓ Getting metadata... ✓ Complete
# [349/2000]   Searching: Javed Ali... ✓ Getting metadata... ✓ Complete
# [350/2000]   Searching: Jack Harlow... ✓ Getting metadata... ✓ Complete
# [351/2000]   Searching: Tyga... ✓ Getting metadata... ✓ Complete
# [352/2000]   Searching: Earth, Wind & Fire... ✓ Getting metadata... ✓ Complete
# [353/2000]   Searching: Nelly... ✓ Getting metadata... ✓ Complete
# [354/2000]   Searching: Perry Como... ✓ Getting metadata... ✓ Complete
# [355/2000]   Searching: The Cure... ✓ Getting metadata... ✓ Complete
# [356/2000]   Searching: MC Meno K... ✓ Getting metadata... ✓ Complete
# [357/2000]   Searching: David Bowie... ✓ Getting metadata... ✓ Complete
# [358/2000]   Searching: Yo Yo Honey Singh... ✓ Getting metadata... ✓ Complete
# [359/2000]   Searching: Burna Boy... ✓ Getting metadata... ✓ Complete
# [360/2000]   Searching: Amy Winehouse... ✓ Getting metadata... ✓ Complete
# [361/2000]   Searching: Anderson .Paak... ✓ Getting metadata... ✓ Complete
# [362/2000]   Searching: Sean Kingston... ✓ Getting metadata... ✓ Complete
# [363/2000]   Searching: U2... ✓ Getting metadata... ✓ Complete
# [364/2000]   Searching: TV Girl... ✓ Getting metadata... ✓ Complete
# [365/2000]   Searching: Nickelback... ✓ Getting metadata... ✓ Complete
# [366/2000]   Searching: beabadoobee... ✓ Getting metadata... ✓ Complete
# [367/2000]   Searching: Chris Rea... ✓ Getting metadata... ✓ Complete
# [368/2000]   Searching: Megan Thee Stallion... ✓ Getting metadata... ✓ Complete
# [369/2000]   Searching: Camilo... ✓ Getting metadata... ✓ Complete
# [370/2000]   Searching: Alok... ✓ Getting metadata... ✓ Complete
# [371/2000]   Searching: De La Soul...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [372/2000]   Searching: Avril Lavigne...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [373/2000]   Searching: Diljit Dosanjh... ✓ Getting metadata... ✓ Complete
# [374/2000]   Searching: Amit Trivedi... ✓ Getting metadata... ✓ Complete
# [375/2000]   Searching: Sachet-Parampara... ✓ Getting metadata... ✓ Complete
# [376/2000]   Searching: Mc Gw... ✓ Getting metadata... ✓ Complete
# [377/2000]   Searching: Kings of Leon... ✓ Getting metadata... ✓ Complete
# [378/2000]   Searching: Omar Courtz... ✓ Getting metadata... ✓ Complete
# [379/2000]   Searching: Boney M.... ✓ Getting metadata... ✓ Complete
# [380/2000]   Searching: Train... ✓ Getting metadata... ✓ Complete
# [381/2000]   Searching: Sebastian Yatra... ✓ Getting metadata... ✓ Complete
# [382/2000]   Searching: W Sound... ✓ Getting metadata... ✓ Complete
# [383/2000]   Searching: Grupo Firme... ✓ Getting metadata... ✓ Complete
# [384/2000]   Searching: MC Ryan SP... ✓ Getting metadata... ✓ Complete
# [385/2000]   Searching: Sachet Tandon... ✓ Getting metadata... ✓ Complete
# [386/2000]   Searching: The Smiths... ✓ Getting metadata... ✓ Complete
# [387/2000]   Searching: Måneskin... ✓ Getting metadata... ✓ Complete
# [388/2000]   Searching: Parampara Tandon... ✓ Getting metadata... ✓ Complete
# [389/2000]   Searching: Prince... ✓ Getting metadata... ✓ Complete
# [390/2000]   Searching: Jess Glynne... ✓ Getting metadata... ✓ Complete
# [391/2000]   Searching: Annie Lennox... ✓ Getting metadata... ✓ Complete
# [392/2000]   Searching: T-Pain... ✓ Getting metadata... ✓ Complete
# [393/2000]   Searching: Disclosure... ✓ Getting metadata... ✓ Complete
# [394/2000]   Searching: Panic! At The Disco... ✓ Getting metadata... ✓ Complete
# [395/2000]   Searching: PinkPantheress... ✓ Getting metadata... ✓ Complete
# [396/2000]   Searching: Andrew Choi... ✓ Getting metadata... ✓ Complete
# [397/2000]   Searching: The Jackson 5... ❌ Not found
# [398/2000]   Searching: Jubin Nautiyal... ✓ Getting metadata... ✓ Complete
# [399/2000]   Searching: Ella Fitzgerald... ✓ Getting metadata... ✓ Complete
# [400/2000]   Searching: The Clash... ✓ Getting metadata... ✓ Complete
# [401/2000]   Searching: Karan Aujla... ✓ Getting metadata... ✓ Complete
# [402/2000]   Searching: Jessie J... ✓ Getting metadata... ✓ Complete
# [403/2000]   Searching: Dolly Parton... ✓ Getting metadata... ✓ Complete
# [404/2000]   Searching: Anu Malik... ✓ Getting metadata... ✓ Complete
# [405/2000]   Searching: Dave... ✓ Getting metadata... ✓ Complete
# [406/2000]   Searching: HUGEL... ✓ Getting metadata... ✓ Complete
# [407/2000]   Searching: Cher... ✓ Getting metadata... ✓ Complete
# [408/2000]   Searching: Coolio... ✓ Getting metadata... ✓ Complete
# [409/2000]   Searching: Mitski... ✓ Getting metadata... ✓ Complete
# [410/2000]   Searching: FloyyMenor... ✓ Getting metadata... ✓ Complete
# [411/2000]   Searching: Limp Bizkit... ✓ Getting metadata... ✓ Complete
# [412/2000]   Searching: Bryson Tiller... ✓ Getting metadata... ✓ Complete
# [413/2000]   Searching: Grupo Menos É Mais... ✓ Getting metadata... ✓ Complete
# [414/2000]   Searching: Lost Frequencies... ✓ Getting metadata... ✓ Complete
# [415/2000]   Searching: B.o.B... ✓ Getting metadata... ✓ Complete
# [416/2000]   Searching: Cyndi Lauper... ✓ Getting metadata... ✓ Complete
# [417/2000]   Searching: She & Him... ✓ Getting metadata... ✓ Complete
# [418/2000]   Searching: R.E.M.... ✓ Getting metadata... ✓ Complete
# [419/2000]   Searching: Gabito Ballesteros... ✓ Getting metadata... ✓ Complete
# [420/2000]   Searching: Daya... ✓ Getting metadata... ✓ Complete
# [421/2000]   Searching: Rahat Fateh Ali Khan... ✓ Getting metadata... ✓ Complete
# [422/2000]   Searching: Shakin' Stevens... ✓ Getting metadata... ✓ Complete
# [423/2000]   Searching: Sajid-Wajid... ✓ Getting metadata... ✓ Complete
# [424/2000]   Searching: Luis R Conriquez... ✓ Getting metadata... ✓ Complete
# [425/2000]   Searching: Marvin Gaye... ✓ Getting metadata... ✓ Complete
# [426/2000]   Searching: Christian Nodal... ✓ Getting metadata... ✓ Complete
# [427/2000]   Searching: Martin Garrix... ✓ Getting metadata... ✓ Complete
# [428/2000]   Searching: BigXthaPlug... ✓ Getting metadata... ✓ Complete
# [429/2000]   Searching: Dido... ✓ Getting metadata... ✓ Complete
# [430/2000]   Searching: Imogen Heap... ✓ Getting metadata... ✓ Complete
# [431/2000]   Searching: Amaal Mallik... ✓ Getting metadata... ✓ Complete
# [432/2000]   Searching: Kapo... ✓ Getting metadata... ✓ Complete
# [433/2000]   Searching: EsDeeKid... ✓ Getting metadata... ✓ Complete
# [434/2000]   Searching: Tulsi Kumar... ✓ Getting metadata... ✓ Complete
# [435/2000]   Searching: Marc Anthony... ✓ Getting metadata... ✓ Complete
# [436/2000]   Searching: Lata Mangeshkar... ✓ Getting metadata... ✓ Complete
# [437/2000]   Searching: Mac DeMarco... ✓ Getting metadata... ✓ Complete
# [438/2000]   Searching: Reik... ✓ Getting metadata... ✓ Complete
# [439/2000]   Searching: Kausar Munir... ✓ Getting metadata... ✓ Complete
# [440/2000]   Searching: Saja Boys... ✓ Getting metadata... ✓ Complete
# [441/2000]   Searching: DJ Khaled... ✓ Getting metadata... ✓ Complete
# [442/2000]   Searching: Rema... ✓ Getting metadata... ✓ Complete
# [443/2000]   Searching: Glass Animals... ✓ Getting metadata... ✓ Complete
# [444/2000]   Searching: Dominic Fike... ✓ Getting metadata... ✓ Complete
# [445/2000]   Searching: Ñengo Flow... ✓ Getting metadata... ✓ Complete
# [446/2000]   Searching: Sech... ✓ Getting metadata... ✓ Complete
# [447/2000]   Searching: YoungBoy Never Broke Again... ✓ Getting metadata... ✓ Complete
# [448/2000]   Searching: Jelly Roll... ✓ Getting metadata... ✓ Complete
# [449/2000]   Searching: Dei V... ✓ Getting metadata... ✓ Complete
# [450/2000]   Searching: AP Dhillon... ✓ Getting metadata... ✓ Complete
# [451/2000]   Searching: F1 The Album... ✓ Getting metadata... ✓ Complete
# [452/2000]   Searching: The Fontane Sisters... ✓ Getting metadata... ✓ Complete
# [453/2000]   Searching: L.V.... ✓ Getting metadata... ✓ Complete
# [454/2000]   Searching: Yandel... ✓ Getting metadata... ✓ Complete
# [455/2000]   Searching: Julión Álvarez y su Norteño Banda... ✓ Getting metadata... ✓ Complete
# [456/2000]   Searching: TWICE... ✓ Getting metadata... ✓ Complete
# [457/2000]   Searching: Band Aid... ✓ Getting metadata... ✓ Complete
# [458/2000]   Searching: Natasha Bedingfield... ✓ Getting metadata... ✓ Complete
# [459/2000]   Searching: Kailash Kher... ✓ Getting metadata... ✓ Complete
# [460/2000]   Searching: Foo Fighters... ✓ Getting metadata... ✓ Complete
# [461/2000]   Searching: Alessia Cara... ✓ Getting metadata... ✓ Complete
# [462/2000]   Searching: Anuv Jain... ✓ Getting metadata... ✓ Complete
# [463/2000]   Searching: S. P. Balasubrahmanyam... ✓ Getting metadata... ✓ Complete
# [464/2000]   Searching: The Offspring... ✓ Getting metadata... ✓ Complete
# [465/2000]   Searching: Summer Walker... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [466/2000]   Searching: Badshah... ✓ Getting metadata... ✓ Complete
# [467/2000]   Searching: Stephen Sanchez... ✓ Getting metadata... ✓ Complete
# [468/2000]   Searching: Chase Atlantic... ✓ Getting metadata... ✓ Complete
# [469/2000]   Searching: Ray Dalton... ✓ Getting metadata... ✓ Complete
# [470/2000]   Searching: Labrinth... ✓ Getting metadata... ✓ Complete
# [471/2000]   Searching: DJ Japa NK... ✓ Getting metadata... ✓ Complete
# [472/2000]   Searching: Carly Rae Jepsen... ✓ Getting metadata... ✓ Complete
# [473/2000]   Searching: Mora... ✓ Getting metadata... ✓ Complete
# [474/2000]   Searching: Shaboozey... ✓ Getting metadata... ✓ Complete
# [475/2000]   Searching: Eurythmics... ✓ Getting metadata... ✓ Complete
# [476/2000]   Searching: Idina Menzel... ✓ Getting metadata... ✓ Complete
# [477/2000]   Searching: Talwiinder... ✓ Getting metadata... ✓ Complete
# [478/2000]   Searching: Xavi... ✓ Getting metadata... ✓ Complete
# [479/2000]   Searching: Led Zeppelin... ✓ Getting metadata... ✓ Complete
# [480/2000]   Searching: *NSYNC... ✓ Getting metadata... ✓ Complete
# [481/2000]   Searching: 5 Seconds of Summer... ✓ Getting metadata... ✓ Complete
# [482/2000]   Searching: Kunaal Vermaa... ✓ Getting metadata... ✓ Complete
# [483/2000]   Searching: KEVIN WOO... ❌ Not found
# [484/2000]   Searching: Danny Chung... ✓ Getting metadata... ✓ Complete
# [485/2000]   Searching: samUIL Lee... ❌ Not found
# [486/2000]   Searching: Neckwav... ✓ Getting metadata... ✓ Complete
# [487/2000]   Searching: Lil Peep... ✓ Getting metadata... ✓ Complete
# [488/2000]   Searching: JVKE... ✓ Getting metadata... ✓ Complete
# [489/2000]   Searching: Dave Stewart... ✓ Getting metadata... ✓ Complete
# [490/2000]   Searching: Macklemore & Ryan Lewis... ✓ Getting metadata... ✓ Complete
# [491/2000]   Searching: Calum Scott... ✓ Getting metadata... ✓ Complete
# [492/2000]   Searching: Bastille...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [493/2000]   Searching: Banda MS de Sergio Lizárraga... ❌ Not found
# [494/2000]   Searching: Marco Antonio Solís... ✓ Getting metadata... ✓ Complete
# [495/2000]   Searching: Roop Kumar Rathod... ✓ Getting metadata... ✓ Complete
# [496/2000]   Searching: Neeti Mohan... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [497/2000]   Searching: Jasmine Sandlas... ✓ Getting metadata... ✓ Complete
# [498/2000]   Searching: Madhubanti Bagchi... ✓ Getting metadata... ✓ Complete
# [499/2000]   Searching: Jonas Blue... ✓ Getting metadata... ✓ Complete
# [500/2000]   Searching: Idgitaf... ✓ Getting metadata... ✓ Complete
# [501/2000]   Searching: Fred again..... ✓ Getting metadata... ✓ Complete
# [502/2000]   Searching: Lil Tecca... ✓ Getting metadata... ✓ Complete
# [503/2000]   Searching: CeeLo Green... ✓ Getting metadata... ✓ Complete
# [504/2000]   Searching: Burl Ives... ✓ Getting metadata... ✓ Complete
# [505/2000]   Searching: GIMS... ✓ Getting metadata... ✓ Complete
# [506/2000]   Searching: Mc Rodrigo do CN... ✓ Getting metadata... ✓ Complete
# [507/2000]   Searching: Justin Quiles... ✓ Getting metadata... ✓ Complete
# [508/2000]   Searching: Los Ángeles Azules... ✓ Getting metadata... ✓ Complete
# [509/2000]   Searching: Bill Withers... ✓ Getting metadata... ✓ Complete
# [510/2000]   Searching: SIENNA SPIRO... ✓ Getting metadata... ✓ Complete
# [511/2000]   Searching: Henrique & Juliano... ✓ Getting metadata... ✓ Complete
# [512/2000]   Searching: Rochak Kohli... ✓ Getting metadata... ✓ Complete
# [513/2000]   Searching: Julieta Venegas... ✓ Getting metadata... ✓ Complete
# [514/2000]   Searching: Foreigner... ✓ Getting metadata... ✓ Complete
# [515/2000]   Searching: Lauv... ✓ Getting metadata... ✓ Complete
# [516/2000]   Searching: The Andrews Sisters... ✓ Getting metadata... ✓ Complete
# [517/2000]   Searching: Alejandro Sanz...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [518/2000]   Searching: MXZI... ✓ Getting metadata... ✓ Complete
# [519/2000]   Searching: Hariharan... ✓ Getting metadata... ✓ Complete
# [520/2000]   Searching: benny blanco... ✓ Getting metadata... ✓ Complete
# [521/2000]   Searching: Juanes... ✓ Getting metadata... ✓ Complete
# [522/2000]   Searching: WizTheMc... ✓ Getting metadata... ✓ Complete
# [523/2000]   Searching: Yan Block... ✓ Getting metadata... ✓ Complete
# [524/2000]   Searching: JID... ✓ Getting metadata... ✓ Complete
# [525/2000]   Searching: Offset... ✓ Getting metadata... ✓ Complete
# [526/2000]   Searching: bees & honey... ✓ Getting metadata... ✓ Complete
# [527/2000]   Searching: Skrillex... ✓ Getting metadata... ✓ Complete
# [528/2000]   Searching: Lil Nas X... ✓ Getting metadata... ✓ Complete
# [529/2000]   Searching: Ayra Starr...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [530/2000]   Searching: Lil Durk... ✓ Getting metadata... ✓ Complete
# [531/2000]   Searching: Eladio Carrion... ✓ Getting metadata... ✓ Complete
# [532/2000]   Searching: Diana Ross... ✓ Getting metadata... ✓ Complete
# [533/2000]   Searching: My Chemical Romance... ✓ Getting metadata... ✓ Complete
# [534/2000]   Searching: Brent Faiyaz... ✓ Getting metadata... ✓ Complete
# [535/2000]   Searching: The 1975... ✓ Getting metadata... ✓ Complete
# [536/2000]   Searching: Sexyy Red... ✓ Getting metadata... ✓ Complete
# [537/2000]   Searching: Troye Sivan... ✓ Getting metadata... ✓ Complete
# [538/2000]   Searching: Mc Jacaré... ✓ Getting metadata... ✓ Complete
# [539/2000]   Searching: Jaani... ✓ Getting metadata... ✓ Complete
# [540/2000]   Searching: Jason Mraz... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [541/2000]   Searching: Robbie Williams... ✓ Getting metadata... ✓ Complete
# [542/2000]   Searching: Ikky... ✓ Getting metadata... ✓ Complete
# [543/2000]   Searching: Alphaville... ✓ Getting metadata... ✓ Complete
# [544/2000]   Searching: Myles Smith... ✓ Getting metadata... ✓ Complete
# [545/2000]   Searching: Young Miko... ✓ Getting metadata... ✓ Complete
# [546/2000]   Searching: Mc Jhey... ✓ Getting metadata... ✓ Complete
# [547/2000]   Searching: blink-182... ✓ Getting metadata... ✓ Complete
# [548/2000]   Searching: The Lumineers... ✓ Getting metadata... ✓ Complete
# [549/2000]   Searching: Christina Perri... ✓ Getting metadata... ✓ Complete
# [550/2000]   Searching: Tones And I... ✓ Getting metadata... ✓ Complete
# [551/2000]   Searching: Jeet Gannguli... ✓ Getting metadata... ✓ Complete
# [552/2000]   Searching: Simone Mendes... ✓ Getting metadata... ✓ Complete
# [553/2000]   Searching: Devi Sri Prasad... ✓ Getting metadata... ✓ Complete
# [554/2000]   Searching: Lenny Tavárez... ✓ Getting metadata... ✓ Complete
# [555/2000]   Searching: Yahritza Y Su Esencia... ✓ Getting metadata... ✓ Complete
# [556/2000]   Searching: Roddy Ricch... ✓ Getting metadata... ✓ Complete
# [557/2000]   Searching: Scorpions... ✓ Getting metadata... ✓ Complete
# [558/2000]   Searching: Mary J. Blige... ✓ Getting metadata... ✓ Complete
# [559/2000]   Searching: Ajay-Atul... ✓ Getting metadata... ✓ Complete
# [560/2000]   Searching: Muse... ✓ Getting metadata... ✓ Complete
# [561/2000]   Searching: Bryant Myers... ✓ Getting metadata... ✓ Complete
# [562/2000]   Searching: Bob Sinclar... ✓ Getting metadata... ✓ Complete
# [563/2000]   Searching: Hotel Ugly... ✓ Getting metadata... ✓ Complete
# [564/2000]   Searching: Little Mix... ✓ Getting metadata... ✓ Complete
# [565/2000]   Searching: Billy Idol... ✓ Getting metadata... ✓ Complete
# [566/2000]   Searching: Nadhif Basalamah... ✓ Getting metadata... ✓ Complete
# [567/2000]   Searching: Chino Pacas... ✓ Getting metadata... ✓ Complete
# [568/2000]   Searching: Maria Becerra... ✓ Getting metadata... ✓ Complete
# [569/2000]   Searching: Joan Sebastian... ✓ Getting metadata... ✓ Complete
# [570/2000]   Searching: Jeremih... ✓ Getting metadata... ✓ Complete
# [571/2000]   Searching: Ella Langley... ✓ Getting metadata... ✓ Complete
# [572/2000]   Searching: Big Sean... ✓ Getting metadata... ✓ Complete
# [573/2000]   Searching: KISS... ✓ Getting metadata... ✓ Complete
# [574/2000]   Searching: Jatin-Lalit... ✓ Getting metadata... ✓ Complete
# [575/2000]   Searching: Arcane... ✓ Getting metadata... ✓ Complete
# [576/2000]   Searching: Benny Dayal... ✓ Getting metadata... ✓ Complete
# [577/2000]   Searching: Mark Ambor... ✓ Getting metadata... ✓ Complete
# [578/2000]   Searching: Kelly Rowland... ✓ Getting metadata... ✓ Complete
# [579/2000]   Searching: GloRilla... ✓ Getting metadata... ✓ Complete
# [580/2000]   Searching: Leona Lewis... ✓ Getting metadata... ✓ Complete
# [581/2000]   Searching: Armaan Malik... ✓ Getting metadata... ✓ Complete
# [582/2000]   Searching: Calle 24... ✓ Getting metadata... ✓ Complete
# [583/2000]   Searching: Zedd... ✓ Getting metadata... ✓ Complete
# [584/2000]   Searching: Kylie Minogue... ✓ Getting metadata... ✓ Complete
# [585/2000]   Searching: FISHER... ✓ Getting metadata... ✓ Complete
# [586/2000]   Searching: Felix Jaehn... ✓ Getting metadata... ✓ Complete
# [587/2000]   Searching: Gotye... ✓ Getting metadata... ✓ Complete
# [588/2000]   Searching: Pearl Jam... ✓ Getting metadata... ✓ Complete
# [589/2000]   Searching: Ricky Martin... ✓ Getting metadata... ✓ Complete
# [590/2000]   Searching: Neha Kakkar... ✓ Getting metadata... ✓ Complete
# [591/2000]   Searching: Asha Bhosle... ✓ Getting metadata... ✓ Complete
# [592/2000]   Searching: Kacey Musgraves... ✓ Getting metadata... ✓ Complete
# [593/2000]   Searching: LE SSERAFIM... ✓ Getting metadata... ✓ Complete
# [594/2000]   Searching: De La Ghetto... ✓ Getting metadata... ✓ Complete
# [595/2000]   Searching: Lynyrd Skynyrd... ✓ Getting metadata... ✓ Complete
# [596/2000]   Searching: Alemán... ✓ Getting metadata... ✓ Complete
# [597/2000]   Searching: Clairo... ✓ Getting metadata... ✓ Complete
# [598/2000]   Searching: Jonita Gandhi... ✓ Getting metadata... ✓ Complete
# [599/2000]   Searching: Alejandro Fernández... ✓ Getting metadata... ✓ Complete
# [600/2000]   Searching: Ana Castela... ✓ Getting metadata... ✓ Complete
# [601/2000]   Searching: Victor Mendivil... ✓ Getting metadata... ✓ Complete
# [602/2000]   Searching: Topic... ✓ Getting metadata... ✓ Complete
# [603/2000]   Searching: A Boogie Wit da Hoodie... ✓ Getting metadata... ✓ Complete
# [604/2000]   Searching: Wale... ✓ Getting metadata... ✓ Complete
# [605/2000]   Searching: Bob Dylan... ✓ Getting metadata... ✓ Complete
# [606/2000]   Searching: Migos... ✓ Getting metadata... ✓ Complete
# [607/2000]   Searching: Stromae... ✓ Getting metadata... ✓ Complete
# [608/2000]   Searching: La Arrolladora Banda El Limón De Rene Camacho... ✓ Getting metadata... ✓ Complete
# [609/2000]   Searching: Deftones... ✓ Getting metadata... ✓ Complete
# [610/2000]   Searching: Calibre 50... ✓ Getting metadata... ✓ Complete
# [611/2000]   Searching: Pop Smoke... ✓ Getting metadata... ✓ Complete
# [612/2000]   Searching: Noriel... ✓ Getting metadata... ✓ Complete
# [613/2000]   Searching: Skepta... ✓ Getting metadata... ✓ Complete
# [614/2000]   Searching: Three Days Grace... ✓ Getting metadata... ✓ Complete
# [615/2000]   Searching: Sukhwinder Singh... ✓ Getting metadata... ✓ Complete
# [616/2000]   Searching: Disturbed... ✓ Getting metadata... ✓ Complete
# [617/2000]   Searching: League of Legends... ✓ Getting metadata... ✓ Complete
# [618/2000]   Searching: Danger Mouse... ✓ Getting metadata... ✓ Complete
# [619/2000]   Searching: Destiny's Child... ✓ Getting metadata... ✓ Complete
# [620/2000]   Searching: Hanumankind... ✓ Getting metadata... ✓ Complete
# [621/2000]   Searching: MGMT... ✓ Getting metadata... ✓ Complete
# [622/2000]   Searching: ILLIT... ✓ Getting metadata... ✓ Complete
# [623/2000]   Searching: Rvssian... ✓ Getting metadata... ✓ Complete
# [624/2000]   Searching: Mon Laferte... ✓ Getting metadata... ✓ Complete
# [625/2000]   Searching: Carlos Vives... ✓ Getting metadata... ✓ Complete
# [626/2000]   Searching: Louis Armstrong... ✓ Getting metadata... ✓ Complete
# [627/2000]   Searching: Lukas Graham... ✓ Getting metadata... ✓ Complete
# [628/2000]   Searching: PNAU... ✓ Getting metadata... ✓ Complete
# [629/2000]   Searching: TINI... ✓ Getting metadata... ✓ Complete
# [630/2000]   Searching: Rex Orange County... ✓ Getting metadata... ✓ Complete
# [631/2000]   Searching: Jung Kook... ✓ Getting metadata... ✓ Complete
# [632/2000]   Searching: Juan Luis Guerra 4.40... ✓ Getting metadata... ✓ Complete
# [633/2000]   Searching: Ruth B.... ✓ Getting metadata... ✓ Complete
# ...
# [1869/2000]   Searching: Blackstreet... ✓ Getting metadata... ✓ Complete
# [1870/2000]   Searching: Tiara Andini... ✓ Getting metadata... ✓ Complete
# [1871/2000]   Searching: Matchbox Twenty... ✓ Getting metadata... ✓ Complete
# [1872/2000]   Searching: Eric Prydz...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1873/2000]   Searching: Franco De Vita... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1874/2000]   Searching: Semicenk... ✓ Getting metadata... ✓ Complete
# [1875/2000]   Searching: New Order... ✓ Getting metadata... ✓ Complete
# [1876/2000]   Searching: Kenia Os... ✓ Getting metadata... ✓ Complete
# [1877/2000]   Searching: Celia Cruz... ✓ Getting metadata... ✓ Complete
# [1878/2000]   Searching: Wicked Movie Cast... ❌ Not found
# [1879/2000]   Searching: Annural Khalid... ✓ Getting metadata... ✓ Complete
# [1880/2000]   Searching: Alan Menken... ✓ Getting metadata... ✓ Complete
# [1881/2000]   Searching: Hyder Dar... ✓ Getting metadata... ✓ Complete
# [1882/2000]   Searching: Mijares... ✓ Getting metadata... ✓ Complete
# [1883/2000]   Searching: Shreyas Puranik... ✓ Getting metadata... ✓ Complete
# [1884/2000]   Searching: Danna Paola... ✓ Getting metadata... ✓ Complete
# [1885/2000]   Searching: José Luis Perales... ✓ Getting metadata... ✓ Complete
# [1886/2000]   Searching: Dj Guuga... ✓ Getting metadata... ✓ Complete
# [1887/2000]   Searching: Zach Top... ✓ Getting metadata... ✓ Complete
# [1888/2000]   Searching: Deorro... ✓ Getting metadata... ✓ Complete
# [1889/2000]   Searching: R.K.M & Ken-Y... ✓ Getting metadata... ✓ Complete
# [1890/2000]   Searching: h6itam... ✓ Getting metadata... ✓ Complete
# [1891/2000]   Searching: Ginuwine... ✓ Getting metadata... ✓ Complete
# [1892/2000]   Searching: The Kooks... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1893/2000]   Searching: SEKIMANE... ✓ Getting metadata... ✓ Complete
# [1894/2000]   Searching: Shinedown... ✓ Getting metadata... ✓ Complete
# [1895/2000]   Searching: ICEDMANE... ✓ Getting metadata... ✓ Complete
# [1896/2000]   Searching: Hikaru Utada... ✓ Getting metadata... ✓ Complete
# [1897/2000]   Searching: Villano Antillano...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1898/2000]   Searching: DYSMANE... ✓ Getting metadata... ✓ Complete
# [1899/2000]   Searching: Pradeep Kumar... ✓ Getting metadata... ✓ Complete
# [1900/2000]   Searching: Carlos Rivera... ✓ Getting metadata... ✓ Complete
# [1901/2000]   Searching: DEV... ✓ Getting metadata... ✓ Complete
# [1902/2000]   Searching: Men I Trust...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1903/2000]   Searching: Angel Y Khriz... ❌ Not found
# [1904/2000]   Searching: Frédéric Chopin... ❌ Not found
# [1905/2000]   Searching: Kahitna... ✓ Getting metadata... ✓ Complete
# [1906/2000]   Searching: Neon Trees... ✓ Getting metadata... ✓ Complete
# [1907/2000]   Searching: Ami Mishra... ✓ Getting metadata... ✓ Complete
# [1908/2000]   Searching: Jessie Reyez... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1909/2000]   Searching: Grupo Mojado... ✓ Getting metadata... ✓ Complete
# [1910/2000]   Searching: Kevin Kaarl... ✓ Getting metadata... ✓ Complete
# [1911/2000]   Searching: Suisei... ✓ Getting metadata... ✓ Complete
# [1912/2000]   Searching: Kiki Dee... ✓ Getting metadata... ✓ Complete
# [1913/2000]   Searching: Vaali... ✓ Getting metadata... ✓ Complete
# [1914/2000]   Searching: Felipe Araújo... ✓ Getting metadata... ✓ Complete
# [1915/2000]   Searching: Alexandra Stan... ✓ Getting metadata... ✓ Complete
# [1916/2000]   Searching: FINNEAS...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1917/2000]   Searching: Bronski Beat... ✓ Getting metadata... ✓ Complete
# [1918/2000]   Searching: Sam Feldt... ✓ Getting metadata... ✓ Complete
# [1919/2000]   Searching: Sam C.S.... ✓ Getting metadata... ✓ Complete
# [1920/2000]   Searching: La T y La M... ✓ Getting metadata... ✓ Complete
# [1921/2000]   Searching: Sleepy Hallow... ✓ Getting metadata... ✓ Complete
# [1922/2000]   Searching: Jenni Rivera... ✓ Getting metadata... ✓ Complete
# [1923/2000]   Searching: The Rish... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1924/2000]   Searching: Diego Verdaguer... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1925/2000]   Searching: Yves Tumor... ✓ Getting metadata... ✓ Complete
# [1926/2000]   Searching: Andra & The Backbone... ✓ Getting metadata... ✓ Complete
# [1927/2000]   Searching: Khruangbin... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1928/2000]   Searching: Vika Jigulina... ✓ Getting metadata... ✓ Complete
# [1929/2000]   Searching: Christopher Cross...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1930/2000]   Searching: Social House... ✓ Getting metadata... ✓ Complete
# [1931/2000]   Searching: Queens of the Stone Age... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1932/2000]   Searching: Third Eye Blind... ✓ Getting metadata... ✓ Complete
# [1933/2000]   Searching: Gloria Estefan... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1934/2000]   Searching: BK... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1935/2000]   Searching: Brenno & Matheus...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1936/2000]   Searching: Dhruv...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1937/2000]   Searching: Jyotica Tangri... ✓ Getting metadata... ✓ Complete
# [1938/2000]   Searching: Darius Rucker... ✓ Getting metadata... ✓ Complete
# [1939/2000]   Searching: -Prey... ✓ Getting metadata... ✓ Complete
# [1940/2000]   Searching: Estelle... ✓ Getting metadata... ✓ Complete
# [1941/2000]   Searching: Natiruts... ✓ Getting metadata... ✓ Complete
# [1942/2000]   Searching: Seventeen... ✓ Getting metadata... ✓ Complete
# [1943/2000]   Searching: DJ Zigão... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1944/2000]   Searching: Gipsy Kings...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1945/2000]   Searching: cjnobeat...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1946/2000]   Searching: LIT killah... ✓ Getting metadata... ✓ Complete
# [1947/2000]   Searching: Yiyo Sarante... ✓ Getting metadata... ✓ Complete
# [1948/2000]   Searching: KEVIN ROLDAN...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1949/2000]   Searching: Anyma... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1950/2000]   Searching: Antonio Vivaldi... ✓ Getting metadata... ✓ Complete
# [1951/2000]   Searching: Dj GM... ✓ Getting metadata... ✓ Complete
# [1952/2000]   Searching: MC Roger... ✓ Getting metadata... ✓ Complete
# [1953/2000]   Searching: Muni Long...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1954/2000]   Searching: Vanessa Carlton... ✓ Getting metadata... ✓ Complete
# [1955/2000]   Searching: MF DOOM... ✓ Getting metadata... ✓ Complete
# [1956/2000]   Searching: PSY... ✓ Getting metadata... ✓ Complete
# [1957/2000]   Searching: Bruno Martini... ✓ Getting metadata... ✓ Complete
# [1958/2000]   Searching: Arivu...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1959/2000]   Searching: Hugh Jackman... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1960/2000]   Searching: wave to earth... ✓ Getting metadata... ✓ Complete
# [1961/2000]   Searching: Randy Travis... ✓ Getting metadata... ✓ Complete
# [1962/2000]   Searching: Redbone... ✓ Getting metadata... ✓ Complete
# [1963/2000]   Searching: Legião Urbana... ✓ Getting metadata... ✓ Complete
# [1964/2000]   Searching: Fenix Flexin... ✓ Getting metadata... ✓ Complete
# [1965/2000]   Searching: PAWSA... ✓ Getting metadata... ✓ Complete
# [1966/2000]   Searching: Iggy Azalea... ✓ Getting metadata... ✓ Complete
# [1967/2000]   Searching: Sandro Cavazza... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1968/2000]   Searching: Los Socios Del Ritmo... ✓ Getting metadata... ✓ Complete
# [1969/2000]   Searching: Grupo Cañaveral De Humberto Pabón... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1970/2000]   Searching: Dom Dolla...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1971/2000]   Searching: Jimi Hendrix... ✓ Getting metadata... ✓ Complete
# [1972/2000]   Searching: Panter Bélico... ❌ Not found
# [1973/2000]   Searching: Tiakola... ✓ Getting metadata... ✓ Complete
# [1974/2000]   Searching: RADWIMPS...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1975/2000]   Searching: Deep Purple... ✓ Getting metadata... ✓ Complete
# [1976/2000]   Searching: Zé Vaqueiro... ✓ Getting metadata... ✓ Complete
# [1977/2000]   Searching: Clinton Cerejo... ✓ Getting metadata... ✓ Complete
# [1978/2000]   Searching: Sheryl Crow... ✓ Getting metadata... ✓ Complete
# [1979/2000]   Searching: Sickick... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1980/2000]   Searching: Whitesnake...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1981/2000]   Searching: Anand Bakshi... ✓ Getting metadata... ✓ Complete
# [1982/2000]   Searching: Chitãozinho & Xororó...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1983/2000]   Searching: Morgan Seatree... ✓ Getting metadata... ✓ Complete
# [1984/2000]   Searching: Hippie Sabotage... ✓ Getting metadata... ✓ Complete
# [1985/2000]   Searching: Rise Against... ✓ Getting metadata... ✓ Complete
# [1986/2000]   Searching: Pineapple StormTv... ✓ Getting metadata... ✓ Complete
# [1987/2000]   Searching: Judy Garland...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1988/2000]   Searching: Shouse...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1989/2000]   Searching: Kunal Ganjawala... ✓ Getting metadata... ✓ Complete
# [1990/2000]   Searching: Soolking... ✓ Getting metadata... ✓ Complete
# [1991/2000]   Searching: Lasso... ✓ Getting metadata...   ❌ Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# [1992/2000]   Searching: Shweta Pandit... ✓ Getting metadata... ✓ Complete
# [1993/2000]   Searching: Jacquees... ✓ Getting metadata... ✓ Complete
# [1994/2000]   Searching: Vaibhav Pani... ✓ Getting metadata... ✓ Complete
# [1995/2000]   Searching: Staind... ✓ Getting metadata... ✓ Complete
# [1996/2000]   Searching: Berliner Philharmoniker... ✓ Getting metadata... ✓ Complete
# [1997/2000]   Searching: Perunggu... ✓ Getting metadata... ✓ Complete
# [1998/2000]   Searching: Pranaay... ✓ Getting metadata... ✓ Complete
# [1999/2000]   Searching: ZMAJOR... ✓ Getting metadata... ✓ Complete
# [2000/2000]   Searching: BM... ✓ Getting metadata... ✓ Complete
#
# ======================================================================
# ✅ Completed: 2000 artists processed
# ======================================================================
#
#
# ======================================================================
# RESULTS SUMMARY
# ======================================================================
# Total artists processed: 2000
# Successful matches: 1727
# Failed matches: 273
#
# DataFrame shape: 2000 rows × 46 columns
#
# 📊 COLUMN HEADERS (Metadata Fields):
#   • artist_mbid
#   • isni
#   • ipi
#   • name
#   • sort_name
#   • type
#   • country
#   • gender
#   • disambiguation
#   • aliases
#   • begin_date
#   • end_date
#   • is_ended
#   • num_albums
#   • num_singles
#   • num_eps
#   • total_releases
#   • total_recordings
#   • genres
#   • tags
#   • rating
#   • rating_votes
#   • official_website
#   • wikipedia
#   • wikidata
#   • discogs
#   • allmusic
#   • imdb
#   • bandcamp
#   • spotify
#   • apple_music
#   • youtube
#   • youtube_music
#   • soundcloud
#   • deezer
#   • tidal
#   • amazon_music
#   • twitter
#   • instagram
#   • facebook
#   • tiktok
#   • linkedin
#   • lyrics
#   • purchase_url
#   • crowdfunding
#   • error
#
#
# Preview of first 5 artists:
#                             artist_mbid              isni  \
# 0  afb680f2-b6eb-4cd7-a70b-a63b25c763d5  0000000117226071
# 1  c8b03190-306c-4120-bb0b-6f2ebfc06ea9  0000000382556637
# 2  e0140a67-e4d1-4f13-8a01-364355bee46e  0000000114791200
# 3  f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387  0000000059110272
# 4  20244d07-534f-4eff-b4d4-930878889970  0000000078519858
#
#                                                  ipi           name  \
# 0              00477487104, 00583145346, 00583145444     Bruno Mars
# 1                                        00574514146     The Weeknd
# 2                           00611935265, 00611935363  Justin Bieber
# 3                                        00664244638  Ariana Grande
# 4  00454808047, 00454808145, 00454808243, 0080435...   Taylor Swift
#
#         sort_name    type country  gender       disambiguation  \
# 0     Mars, Bruno  Person      US    Male            US singer
# 1     Weeknd, The  Person      CA    Male  Canadian R&B singer
# 2  Bieber, Justin  Person      CA    Male
# 3  Grande, Ariana  Person      US  Female
# 4   Swift, Taylor  Person      US  Female
#
#                                              aliases  ... amazon_music  \
# 0  Bruno Mars, Bruno Mars, Peter Gene Hernandez, ...  ...
# 1  Abel Makkonen Tesfaye, Abel Tesfaye, The Weeke...  ...
# 2  Justin Beiber, Justin Bieber, Justin Drew Bieb...  ...
# 3  Ariana Grande-Butera, אריאנא גראנדע, آریانا گر...  ...
# 4  Dr. Taylor Alison Swift, Nils Sjöberg, T-Swizz...  ...
#
#   twitter instagram  facebook  tiktok  linkedin  \
# 0
# 1
# 2
# 3
# 4
#
#                                               lyrics  \
# 0       https://www.musixmatch.com/artist/Bruno-Mars
# 1       https://www.musixmatch.com/artist/The-Weeknd
# 2    https://www.musixmatch.com/artist/Justin-Bieber
# 3  http://www.directlyrics.com/ariana-grande-arti...
# 4     https://www.musixmatch.com/artist/Taylor-Swift
#
#                                         purchase_url crowdfunding error
# 0                                                                   NaN
# 1         https://www.cdjapan.co.jp/person/700613925                NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4  https://www.yesasia.com/0-aid1895644-0-bpt.47-...                NaN
#
# [5 rows x 46 columns]
# 💾 SAVE OPTIONS:
#   df_artists.to_csv('top_artists_metadata.csv', index=False)
#   df_artists.to_json('top_artists_metadata.json', orient='records')
#   df_artists.to_excel('top_artists_metadata.xlsx', index=False)
#
# ✅ Ready! DataFrame stored in variable: df_artists

# %%
# @title Export to CSV
df_artists.to_csv('top_artists_metadata.csv', index=False)
print("✅ Exported to: top_artists_metadata.csv")
# Out:
# ✅ Exported to: top_artists_metadata.csv
